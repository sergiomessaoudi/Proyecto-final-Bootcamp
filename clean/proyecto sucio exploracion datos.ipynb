# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **2015**  **DATAFRAME 1**

# %%
df= pd.read_csv('data/raw_data/2015.csv')
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
df = df.drop(columns=['Region','Standard Error','Dystopia Residual'])
df.head(1)
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
#
#    Generosity
# 0     0.29678

# %%
dflimpio = df.rename(columns={'Happiness Rank': 'Overall rank', 'Happiness Score': 'Score','Family':'Social Support','Economy (GDP per Capita)':'GDP per capita','Trust (Government Corruption)':'Perceptions of corruption'})
dflimpio.head(2)
# Out:
#        Country  Overall rank  Score  GDP per capita  Social Support  \
# 0  Switzerland             1  7.587         1.39651         1.34951
# 1      Iceland             2  7.561         1.30232         1.40223
#
#    Health (Life Expectancy)  Freedom  Perceptions of corruption  Generosity
# 0                   0.94143  0.66557                    0.41978     0.29678
# 1                   0.94784  0.62877                    0.14145     0.43630

# %%
df1final = dflimpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social Support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df1final
# Out:
#      Overall rank      Country  Score  GDP per capita  Social Support  \
# 0               1  Switzerland  7.587         1.39651         1.34951
# 1               2      Iceland  7.561         1.30232         1.40223
# 2               3      Denmark  7.527         1.32548         1.36058
# 3               4       Norway  7.522         1.45900         1.33095
# 4               5       Canada  7.427         1.32629         1.32261
# ..            ...          ...    ...             ...             ...
# 153           154       Rwanda  3.465         0.22208         0.77370
# 154           155        Benin  3.340         0.28665         0.35386
# 155           156        Syria  3.006         0.66320         0.47489
# 156           157      Burundi  2.905         0.01530         0.41587
# 157           158         Togo  2.839         0.20868         0.13995
#
#      Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# ...

# %%
df1final.shape
# Out:
# (158, 9)

# %%
df1limpio= df1final

# %%
df1final.to_excel("2015limpio.xlsx") # TERMINADO PARECE

# %% [markdown]
# **DATAFRAME 2** **2016**

# %%
df2= pd.read_csv('data/raw_data/2016.csv')
df2.shape
# Out:
# (157, 13)

# %%
df2.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df2.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
df2 = df2.drop(columns=['Region','Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual'])
df2.head(1)
# Out:
#    Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Denmark               1            7.526                   1.44178
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.16374                   0.79504  0.57941                        0.44453
#
#    Generosity
# 0     0.36171

# %%
df2limpio = df2.rename(columns={'Happiness Rank': 'Overall rank', 'Happiness Score': 'Score','Family':'Social Support','Economy (GDP per Capita)':'GDP per capita','Trust (Government Corruption)':'Perceptions of corruption'})
df2limpio.head(2)
# Out:
#        Country  Overall rank  Score  GDP per capita  Social Support  \
# 0      Denmark             1  7.526         1.44178         1.16374
# 1  Switzerland             2  7.509         1.52733         1.14524
#
#    Health (Life Expectancy)  Freedom  Perceptions of corruption  Generosity
# 0                   0.79504  0.57941                    0.44453     0.36171
# 1                   0.86303  0.58557                    0.41203     0.28083

# %%
df2final = df2limpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social Support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df2final.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Denmark  7.526         1.44178         1.16374
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.79504  0.57941     0.36171                    0.44453

# %%
df2limpio= df2final

# %%
df2final.to_excel("2016limpio.xlsx") # TERMINADO PARECE

# %% [markdown]
# **DATAFRAME 3** **2017**

# %%
df3= pd.read_csv('data/raw_data/2017.csv')
df3.shape
# Out:
# (155, 12)

# %%
df3.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df3.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
df3 = df3.drop(columns=['Whisker.high','Whisker.low','Dystopia.Residual'])
df3.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0  Norway               1            7.537                  1.616463
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
#
#    Trust..Government.Corruption.
# 0                       0.315964

# %%
df3limpio = df3.rename(columns={'Happiness.Rank': 'Overall rank', 'Happiness.Score': 'Score','Family':'Social Support','Economy..GDP.per.Capita.':'GDP per capita','Trust..Government.Corruption.':'Perceptions of corruption','Health..Life.Expectancy.':'Health (Life Expectancy)'})
df3limpio.head(2)
# Out:
#    Country  Overall rank  Score  GDP per capita  Social Support  \
# 0   Norway             1  7.537        1.616463        1.533524
# 1  Denmark             2  7.522        1.482383        1.551122
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.796667  0.635423    0.362012                   0.315964
# 1                  0.792566  0.626007    0.355280                   0.400770

# %%
df3final = df3limpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social Support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df3final.head(1)
# Out:
#    Overall rank Country  Score  GDP per capita  Social Support  \
# 0             1  Norway  7.537        1.616463        1.533524
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.796667  0.635423    0.362012                   0.315964

# %%
df3limpio= df3final

# %%
df3final.to_excel("2017limpio.xlsx") # TERMINADO PARECE

# %% [markdown]
# **DF4**  **2018**

# %%
df4= pd.read_csv('data/raw_data/2018.csv')
df4.shape
# Out:
# (156, 9)

# %%
df4.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df4
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df4limpio = df4.rename(columns={'Country or region': 'Country', 'Freedom to make life choices': 'Freedom'})

# %%
df4limpio= df4limpio.rename(columns={'Healthy life expectancy':'Health (Life Expectancy)'})
df4limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social support  \
# 0             1  Finland  7.632           1.305           1.592
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.874    0.681       0.202                      0.393

# %%
df4limpio=df4limpio.rename(columns={'Social support':'Social Support'})

# %%
df4limpio
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social Support  Health (Life Expectancy)  Freedom  Generosity  \
# 0             1.592                     0.874    0.681       0.202
# ...

# %%
df4limpio.to_excel("2018limpio.xlsx")

# %% [markdown]
# **DF5** **2019**

# %%
df5= pd.read_csv('data/raw_data/2019.csv')
df5.shape
# Out:
# (156, 9)

# %%
df5.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df5limpio = df5.rename(columns={'Healthy life expectancy':'Health (Life Expectancy)','Country or region': 'Country', 'Freedom to make life choices': 'Freedom'})

# %%
df5limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social support  \
# 0             1  Finland  7.769            1.34           1.587
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.986    0.596       0.153                      0.393

# %%
df5limpio = df5.rename(columns={'Social support':'Social Support','Country or region':'Country'})
df5limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
df5limpio.to_excel("2019limpio.xlsx")

# %% [markdown]
# **DF6** **2020**

# %%
df6= pd.read_csv('data/raw_data/2020.csv')
df6.shape
# Out:
# (153, 20)

# %%
df6.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df6.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                           1.28519
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
# ...

# %%
df6limpio = df6.drop(columns=['Logged GDP per capita','Explained by: Social support','Regional indicator','Standard error of ladder score','upperwhisker','lowerwhisker','Ladder score in Dystopia','Dystopia + residual'])
df6limpio.head(1)
# Out:
#   Country name  Ladder score  Social support  Healthy life expectancy  \
# 0      Finland        7.8087         0.95433                71.900825
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
#
#    Explained by: Log GDP per capita  Explained by: Healthy life expectancy  \
# 0                           1.28519                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
#    Explained by: Perceptions of corruption
# 0                                 0.477857

# %%
df6limpio = df6limpio.drop(columns=['Freedom to make life choices','Generosity','Perceptions of corruption','Healthy life expectancy'])
df6limpio.head(1)
# Out:
#   Country name  Ladder score  Social support  \
# 0      Finland        7.8087         0.95433
#
#    Explained by: Log GDP per capita  Explained by: Healthy life expectancy  \
# 0                           1.28519                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
#    Explained by: Perceptions of corruption
# 0                                 0.477857

# %%
df6limpio = df6limpio.rename(columns={'Country name':'Country',"Ladder score":"Score","Explained by: Log GDP per capita":'GDP per capita','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Generosity':'Generosity','Explained by: Perceptions of corruption':'Perceptions of corruption'})
df6limpio.head(1)
# Out:
#    Country   Score  Social support  GDP per capita  Health (Life Expectancy)  \
# 0  Finland  7.8087         0.95433         1.28519                  0.961271
#
#     Freedom  Generosity  Perceptions of corruption
# 0  0.662317     0.15967                   0.477857

# %%
df6limpio['Overall rank'] = [i+1 for i in range(len(df6limpio))]
df6limpio.head(1)
# Out:
#    Country   Score  Social support  GDP per capita  Health (Life Expectancy)  \
# 0  Finland  7.8087         0.95433         1.28519                  0.961271
#
#     Freedom  Generosity  Perceptions of corruption  Overall rank
# 0  0.662317     0.15967                   0.477857             1

# %%
df6limpio = df6limpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df6limpio.head(2)
# Out:
#    Overall rank  Country   Score  GDP per capita  Social support  \
# 0             1  Finland  7.8087        1.285190        0.954330
# 1             2  Denmark  7.6456        1.326949        0.955991
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.961271  0.662317    0.159670                   0.477857
# 1                  0.979333  0.665040    0.242793                   0.495260

# %%
df6limpio= df6limpio.rename(columns={'Social support':'Social Support'})
df6limpio.head(1)
# Out:
#    Overall rank  Country   Score  GDP per capita  Social Support  \
# 0             1  Finland  7.8087         1.28519         0.95433
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.961271  0.662317     0.15967                   0.477857

# %% [markdown]
# **DF7** **2021**

# %%
df7= pd.read_csv('data/raw_data/2021.csv')
df7.shape
# Out:
# (149, 20)

# %%
df7.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df7limpio = df7.drop(columns=['Social support','Freedom to make life choices','Healthy life expectancy','Regional indicator',"Standard error of ladder score",'upperwhisker','lowerwhisker','Logged GDP per capita','Generosity','Dystopia + residual','Perceptions of corruption','Ladder score in Dystopia'])
df7limpio.head(1)
# Out:
#   Country name  Ladder score  Explained by: Log GDP per capita  \
# 0      Finland         7.842                             1.446
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.106                                  0.741
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.691                     0.124
#
#    Explained by: Perceptions of corruption
# 0                                    0.481

# %%
df7limpio = df7limpio.rename(columns={'Explained by: Social support':'Social support','Country name':'Country',"Ladder score":"Score","Explained by: Log GDP per capita":'GDP per capita','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Generosity':'Generosity','Explained by: Perceptions of corruption':'Perceptions of corruption'})
df7limpio.head(1)
# Out:
#    Country  Score  GDP per capita  Social support  Health (Life Expectancy)  \
# 0  Finland  7.842           1.446           1.106                     0.741
#
#    Freedom  Generosity  Perceptions of corruption
# 0    0.691       0.124                      0.481

# %%
df7limpio['Overall rank'] = [i+1 for i in range(len(df7limpio))]
df7limpio.head(1)
# Out:
#    Country  Score  GDP per capita  Social support  Health (Life Expectancy)  \
# 0  Finland  7.842           1.446           1.106                     0.741
#
#    Freedom  Generosity  Perceptions of corruption  Overall rank
# 0    0.691       0.124                      0.481             1

# %%
df7limpio = df7limpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df7limpio.head(2)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social support  \
# 0             1  Finland  7.842           1.446           1.106
# 1             2  Denmark  7.620           1.502           1.108
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.741    0.691       0.124                      0.481
# 1                     0.763    0.686       0.208                      0.485

# %%
df7limpio= df7limpio.rename(columns={'Social support':'Social Support'})
df6limpio.head(1)
# Out:
#    Overall rank  Country   Score  GDP per capita  Social Support  \
# 0             1  Finland  7.8087         1.28519         0.95433
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.961271  0.662317     0.15967                   0.477857

# %% [markdown]
# **DF8** **2022**

# %%
df8= pd.read_csv('data/raw_data/2022.csv')
df8.shape
# Out:
# (147, 12)

# %%
df8.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
df8limpio = df8.drop(columns=['Whisker-high','Whisker-low','Dystopia (1.83) + residual'])
df8limpio.head(1)
# Out:
#    RANK  Country Happiness score Explained by: GDP per capita  \
# 0     1  Finland           7,821                        1,892
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
#
#   Explained by: Freedom to make life choices Explained by: Generosity  \
# 0                                      0,736                    0,109
#
#   Explained by: Perceptions of corruption
# 0                                   0,534

# %%
df8limpio = df8limpio.rename(columns={'RANK':'Overall rank','Happiness score':'Score','Explained by: GDP per capita':'GDP per capita','Explained by: Social support':'Social support','Explained by: Healthy life expectancy':'Health (Life Expectancy)','Explained by: Freedom to make life choices':'Freedom','Explained by: Generosity':'Generosity',"Explained by: Perceptions of corruption":'Perceptions of corruption'})

# %%
df8limpio = df8limpio.reindex(columns=['Overall rank','Country','Score','GDP per capita','Social support','Health (Life Expectancy)','Freedom','Generosity','Perceptions of corruption'])
df8limpio.head(2)
# Out:
#    Overall rank  Country  Score GDP per capita Social support  \
# 0             1  Finland  7,821          1,892          1,258
# 1             2  Denmark  7,636          1,953          1,243
#
#   Health (Life Expectancy) Freedom Generosity Perceptions of corruption
# 0                    0,775   0,736      0,109                     0,534
# 1                    0,777   0,719      0,188                     0,532

# %%
df8limpio= df8limpio.rename(columns={'Social support':'Social Support'})
df8limpio.head(1)
# Out:
#    Overall rank  Country  Score GDP per capita Social Support  \
# 0             1  Finland  7,821          1,892          1,258
#
#   Health (Life Expectancy) Freedom Generosity Perceptions of corruption
# 0                    0,775   0,736      0,109                     0,534

# %% [markdown]
# #~###---------------------------------------------------------------------------------------------------------------------

# %%
df1limpio.shape,df2limpio.shape,df3limpio.shape,df4limpio.shape,df5limpio.shape,df6limpio.shape,df7limpio.shape,df8limpio.shape
# Out:
# ((158, 9),
#  (157, 9),
#  (155, 9),
#  (156, 9),
#  (156, 9),
#  (153, 9),
#  (149, 9),
#  (147, 9))

# %%
for pais in df1final.Country.unique():
    if pais not in df8limpio.Country.unique():
        print(pais)
# Out:
# Luxembourg
# Oman
# Qatar
# Czech Republic
# Taiwan
# Kuwait
# Suriname
# Trinidad and Tobago
# Guatemala
# Belarus
# Libya
# North Cyprus
# Turkmenistan
# Hong Kong
# Bhutan
# Azerbaijan
# Somaliland region
# Macedonia
# Lesotho
# Swaziland
# Palestinian Territories
# Liberia
# Sudan
# Haiti
# Congo (Kinshasa)
# Mauritania
# Djibouti
# Botswana
# Yemen
# Angola
# Congo (Brazzaville)
# Comoros
# Niger
# Madagascar
# Central African Republic
# Chad
# Rwanda
# Syria
# Burundi

# %%
df1limpio.head(1)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social Support  \
# 0             1  Switzerland  7.587         1.39651         1.34951
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.94143  0.66557     0.29678                    0.41978

# %%
df2limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Denmark  7.526         1.44178         1.16374
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.79504  0.57941     0.36171                    0.44453

# %%
df3limpio.head(1)
# Out:
#    Overall rank Country  Score  GDP per capita  Social Support  \
# 0             1  Norway  7.537        1.616463        1.533524
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.796667  0.635423    0.362012                   0.315964

# %%
df4limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.632           1.305           1.592
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.874    0.681       0.202                      0.393

# %%
df5limpio.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social Support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
df6limpio.head(1)
# Out:
#    Overall rank  Country   Score  GDP per capita  Social Support  \
# 0             1  Finland  7.8087         1.28519         0.95433
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.961271  0.662317     0.15967                   0.477857

# %%
df7limpio.head(1)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.842           1.446           1.106
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.741    0.691       0.124                      0.481

# %%
df8limpio.head(1)
# Out:
#    Overall rank  Country  Score GDP per capita Social Support  \
# 0             1  Finland  7,821          1,892          1,258
#
#   Health (Life Expectancy) Freedom Generosity Perceptions of corruption
# 0                    0,775   0,736      0,109                     0,534

# %%
df8limpio.columns
# Out:
# Index(['Overall rank', 'Country', 'Score', 'GDP per capita', 'Social Support',
#        'Health (Life Expectancy)', 'Freedom', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
dfs = [df1limpio, df2limpio,df3limpio,df4limpio,df5limpio,df6limpio,df7limpio,df8limpio]

mezcla = np.array('Mi casa')
for i, df in enumerate(dfs):
    print(i)
    mezcla = np.append(mezcla, df.Country.unique())

mezcla
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# array(['Mi casa', 'Switzerland', 'Iceland', ..., 'Lebanon', 'Afghanistan',
#        'xx'], dtype=object)

# %%
df5limpio
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social Support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
mezcla.tolist()
# Out:
# ['Mi casa',
#  'Switzerland',
#  'Iceland',
#  'Denmark',
#  'Norway',
#  'Canada',
#  'Finland',
#  'Netherlands',
#  'Sweden',
#  'New Zealand',
#  'Australia',
#  'Israel',
#  'Costa Rica',
#  'Austria',
#  'Mexico',
#  'United States',
#  'Brazil',
#  'Luxembourg',
#  'Ireland',
#  'Belgium',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Oman',
#  'Venezuela',
#  'Singapore',
#  'Panama',
#  'Germany',
#  'Chile',
#  'Qatar',
#  'France',
#  'Argentina',
#  'Czech Republic',
#  'Uruguay',
#  'Colombia',
#  'Thailand',
#  'Saudi Arabia',
#  'Spain',
#  'Malta',
#  'Taiwan',
#  'Kuwait',
#  'Suriname',
#  'Trinidad and Tobago',
#  'El Salvador',
#  'Guatemala',
#  'Uzbekistan',
#  'Slovakia',
#  'Japan',
#  'South Korea',
#  'Ecuador',
#  'Bahrain',
#  'Italy',
#  'Bolivia',
#  'Moldova',
#  'Paraguay',
#  'Kazakhstan',
#  'Slovenia',
#  'Lithuania',
#  'Nicaragua',
#  'Peru',
#  'Belarus',
#  'Poland',
#  'Malaysia',
#  'Croatia',
#  'Libya',
#  'Russia',
#  'Jamaica',
# ...

# %%
unique, counts = np.unique(mezcla, return_counts=True)

in_all_df = [country for country, count in zip(unique, counts) if count == max(counts)]
in_all_df
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guinea',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lebanon',
#  'Lithuania',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
# ...

# %%
len(unique) # de 197 paises que hay en total, pasamos a 117 que son los que se repiten en los 8 csv
# Out:
# 197

# %%
len(in_all_df)  # Tengo que dejar solamente 117 paises que se repiten en los 8 dataframe
# Out:
# 117

# %% [markdown]
# **LIMPIEZA PAISES**

# %%
df1limpio.head(2)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social Support  \
# 0             1  Switzerland  7.587         1.39651         1.34951
# 1             2      Iceland  7.561         1.30232         1.40223
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.94143  0.66557     0.29678                    0.41978
# 1                   0.94784  0.62877     0.43630                    0.14145

# %%
df1_filt = df1limpio[df1limpio.Country.isin(in_all_df)]
df1_filt.head(2)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social Support  \
# 0             1  Switzerland  7.587         1.39651         1.34951
# 1             2      Iceland  7.561         1.30232         1.40223
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.94143  0.66557     0.29678                    0.41978
# 1                   0.94784  0.62877     0.43630                    0.14145

# %%
df1_filt.shape
# Out:
# (117, 9)

# %%
df2_filt = df2limpio[df2limpio.Country.isin(in_all_df)]
df2_filt.head(2)
# Out:
#    Overall rank      Country  Score  GDP per capita  Social Support  \
# 0             1      Denmark  7.526         1.44178         1.16374
# 1             2  Switzerland  7.509         1.52733         1.14524
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                   0.79504  0.57941     0.36171                    0.44453
# 1                   0.86303  0.58557     0.28083                    0.41203

# %%
df2_filt.shape
# Out:
# (117, 9)

# %%
df3_filt = df3limpio[df2limpio.Country.isin(in_all_df)]
df3_filt.head(2)
# Out:
# <ipython-input-92-56f4615461b8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3_filt = df3limpio[df2limpio.Country.isin(in_all_df)]
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1   Norway  7.537        1.616463        1.533524
# 1             2  Denmark  7.522        1.482383        1.551122
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.796667  0.635423    0.362012                   0.315964
# 1                  0.792566  0.626007    0.355280                   0.400770

# %%
df3_filt.shape
# Out:
# (117, 9)

# %%
df4_filt = df4limpio[df4limpio.Country.isin(in_all_df)]
df4_filt.head(2)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.632           1.305           1.592
# 1             2   Norway  7.594           1.456           1.582
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.874    0.681       0.202                      0.393
# 1                     0.861    0.686       0.286                      0.340

# %%
df4_filt.shape
# Out:
# (117, 9)

# %%
df5_filt = df5limpio[df5limpio.Country.isin(in_all_df)]
df5_filt.head(2)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.769           1.340           1.587
# 1             2  Denmark  7.600           1.383           1.573
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410

# %%
df5_filt.shape
# Out:
# (117, 9)

# %%
df6_filt = df6limpio[df6limpio.Country.isin(in_all_df)]
df6_filt.head(2)
# Out:
#    Overall rank  Country   Score  GDP per capita  Social Support  \
# 0             1  Finland  7.8087        1.285190        0.954330
# 1             2  Denmark  7.6456        1.326949        0.955991
#
#    Health (Life Expectancy)   Freedom  Generosity  Perceptions of corruption
# 0                  0.961271  0.662317    0.159670                   0.477857
# 1                  0.979333  0.665040    0.242793                   0.495260

# %%
df6_filt.shape
# Out:
# (117, 9)

# %%
df7_filt = df7limpio[df7limpio.Country.isin(in_all_df)]
df7_filt.head(2)
# Out:
#    Overall rank  Country  Score  GDP per capita  Social Support  \
# 0             1  Finland  7.842           1.446           1.106
# 1             2  Denmark  7.620           1.502           1.108
#
#    Health (Life Expectancy)  Freedom  Generosity  Perceptions of corruption
# 0                     0.741    0.691       0.124                      0.481
# 1                     0.763    0.686       0.208                      0.485

# %%
df7_filt.shape
# Out:
# (117, 9)

# %%
df8_filt = df8limpio[df8limpio.Country.isin(in_all_df)]
df8_filt.head(2)
# Out:
#    Overall rank  Country  Score GDP per capita Social Support  \
# 0             1  Finland  7,821          1,892          1,258
# 1             2  Denmark  7,636          1,953          1,243
#
#   Health (Life Expectancy) Freedom Generosity Perceptions of corruption
# 0                    0,775   0,736      0,109                     0,534
# 1                    0,777   0,719      0,188                     0,532

# %%
df8_filt.shape
# Out:
# (117, 9)

# %%
a = df1_filt.copy()
a['Year'] = 2015

b = df2_filt.copy()       
b['Year'] = 2016

c = df3_filt.copy()
c['Year'] = 2017

d = df4_filt.copy()
d['Year'] = 2018

e= df5_filt.copy()
e['Year'] = 2019

f= df6_filt.copy()
f['Year'] = 2020

g= df7_filt.copy()
g['Year'] = 2021

h= df8_filt.copy()
h['Year'] = 2022

# %%
cuenta = pd.concat([a, b,c,d,e,f,g,h])
cuenta.Country.value_counts()
# Out:
# Switzerland                 8
# Zambia                      8
# Greece                      8
# Mongolia                    8
# Dominican Republic          8
#                            ..
# Taiwan Province of China    1
# Guatemala                   1
# Czech Republic              1
# Luxembourg                  1
# Central African Republic    1
# Name: Country, Length: 142, dtype: int64

# %%
cuenta
# Out:
#      Overall rank       Country  Score GDP per capita Social Support  \
# 0               1   Switzerland  7.587        1.39651        1.34951
# 1               2       Iceland  7.561        1.30232        1.40223
# 2               3       Denmark  7.527        1.32548        1.36058
# 3               4        Norway  7.522          1.459        1.33095
# 4               5        Canada  7.427        1.32629        1.32261
# ..            ...           ...    ...            ...            ...
# 138           139      Tanzania  3,702          0,848          0,597
# 139           140  Sierra Leone  3,574          0,686          0,416
# 143           144      Zimbabwe  2,995          0,947          0,690
# 144           145       Lebanon  2,955          1,392          0,498
# 145           146   Afghanistan  2,404          0,758          0,000
#
#     Health (Life Expectancy)  Freedom Generosity Perceptions of corruption  \
# ...

# %%
cuenta = cuenta.drop(columns=['Healthy life expectancy','Freedom to make life choices'])
cuenta.head(1)
# Out:
#    Overall rank      Country  Score GDP per capita Social Support  \
# 0             1  Switzerland  7.587        1.39651        1.34951
#
#   Health (Life Expectancy)  Freedom Generosity Perceptions of corruption  Year
# 0                  0.94143  0.66557    0.29678                   0.41978  2015

# %%
cuenta.shape
# Out:
# (936, 10)

# %%
cuenta.to_excel("paises2015_2022.xlsx")
