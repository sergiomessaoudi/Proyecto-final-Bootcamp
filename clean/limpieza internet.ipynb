# %%
import pandas as pd

# %%
df = pd.read_csv('data/interneto.csv',encoding="ISO-8859-1",skiprows=6)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-1a018d4ece2a> in <module>
# ----> 1 df = pd.read_csv('data/internet.csv',encoding="ISO-8859-1",skiprows=6)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.isna().sum()

# %%
df= df.iloc[0:195]
infointernet= df.iloc[195:]

# %%
dfinternet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d4d584339ce5> in <module>
# ----> 1 dfinternet
#
# NameError: name 'dfinternet' is not defined

# %%
df.tail(20)
# Out:
#     HDI Rank                              Country  2000  Unnamed: 3  2005  \
# 175      167                                 Togo   0.8         NaN   1.8
# 176      104                                Tonga   2.4         NaN   4.9
# 177       67                  Trinidad and Tobago   7.7         NaN  29.0
# 178       95                              Tunisia   2.8         NaN   9.7
# 179       54                               Turkey   3.8         NaN  15.5
# 180      111                         Turkmenistan   0.1         NaN   1.0
# 181       ..                               Tuvalu   5.2         NaN   5.2
# 182      159                               Uganda   0.2         NaN   1.7
# 183       74                              Ukraine   0.7         NaN   3.8
# 184       31                 United Arab Emirates  23.6         NaN  40.0
# 185       13                       United Kingdom  26.8         NaN  70.0
# 186       17                        United States  43.1         NaN  68.0
# ...

# %%
def reorganizar(df,colyear):    
    df2 = df[["Country",colyear]]
    df2["year"]=int(colyear)
    df2.columns = ['Country','Internet',"year"]
    return df2

# %%
df2015 = reorganizar(df,"2015")
df2016 = reorganizar(df,"2016")
df2017 = reorganizar(df,"2017")
df2018 = reorganizar(df,"2018")
# Out:
# <ipython-input-9-7a1ea2cb868b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["year"]=int(colyear)
# <ipython-input-9-7a1ea2cb868b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["year"]=int(colyear)
# <ipython-input-9-7a1ea2cb868b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2017
# Out:
#                                  Country Internet  year
# 0                            Afghanistan     13.5  2017
# 1                                Albania     71.8  2017
# 2                                Algeria     47.7  2017
# 3                                Andorra     91.6  2017
# 4                                 Angola     14.3  2017
# ..                                   ...      ...   ...
# 190   Venezuela (Bolivarian Republic of)     72.0  2017
# 191                             Viet Nam     58.1  2017
# 192                                Yemen     26.7  2017
# 193                               Zambia     27.9  2017
# 194                             Zimbabwe     27.1  2017
#
# [195 rows x 3 columns]

# %%
df2018
# Out:
#                                  Country Internet  year
# 0                            Afghanistan     13.5  2018
# 1                                Albania     71.8  2018
# 2                                Algeria     59.6  2018
# 3                                Andorra     91.6  2018
# 4                                 Angola     14.3  2018
# ..                                   ...      ...   ...
# 190   Venezuela (Bolivarian Republic of)     72.0  2018
# 191                             Viet Nam     70.3  2018
# 192                                Yemen     26.7  2018
# 193                               Zambia     14.3  2018
# 194                             Zimbabwe     27.1  2018
#
# [195 rows x 3 columns]

# %%
internetjunto= pd.concat([df2015,df2016,df2017,df2018])
internetjunto
# Out:
#                                  Country Internet  year
# 0                            Afghanistan      8.3  2015
# 1                                Albania     63.3  2015
# 2                                Algeria     38.2  2015
# 3                                Andorra     96.9  2015
# 4                                 Angola     12.4  2015
# ..                                   ...      ...   ...
# 190   Venezuela (Bolivarian Republic of)     72.0  2018
# 191                             Viet Nam     70.3  2018
# 192                                Yemen     26.7  2018
# 193                               Zambia     14.3  2018
# 194                             Zimbabwe     27.1  2018
#
# [780 rows x 3 columns]

# %%
internetjunto.to_excel('internet2015_2018.xlsx')

# %%
#--------------------------------------------------------------------------------------------------------------

# %%
df2 = pd.read_excel('data/salud.xlsx')

# %%
df2
# Out:
#                                            serie Name  \
# 0             Life expectancy at birth, total (years)
# 1             Life expectancy at birth, total (years)
# 2             Life expectancy at birth, total (years)
# 3             Life expectancy at birth, total (years)
# 4             Life expectancy at birth, total (years)
# 5             Life expectancy at birth, total (years)
# 6            Fertility rate, total (births per woman)
# 7            Fertility rate, total (births per woman)
# 8            Fertility rate, total (births per woman)
# 9            Fertility rate, total (births per woman)
# 10           Fertility rate, total (births per woman)
# 11           Fertility rate, total (births per woman)
# 12                Mortality rate, under-5 (per 1,000)
# 13                Mortality rate, under-5 (per 1,000)
# 14                Mortality rate, under-5 (per 1,000)
# 15                Mortality rate, under-5 (per 1,000)
# ...

# %%
data = pd.read_excel('')
