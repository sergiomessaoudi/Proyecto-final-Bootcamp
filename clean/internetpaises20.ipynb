# %%
import pandas as pd

# %% [markdown]
# **ACCESO INTERNET**

# %%
df = pd.read_excel('sucio/interneto.xlsx')

# %%
df.head(20)
# Out:
#           Country Name Country Code  \
# 0       United Kingdom          GBR
# 1        United States          USA
# 2               Canada          CAN
# 3            Australia          AUS
# 4               Brazil          BRA
# 5   Russian Federation          RUS
# 6                India          IND
# 7                China          CHN
# 8         South Africa          ZAF
# 9                Spain          ESP
# 10            Portugal          PRT
# 11              France          FRA
# 12               Italy          ITA
# 13             Germany          DEU
# 14             Finland          FIN
# 15            Bulgaria          BGR
# 16             Romania          ROU
# 17             Hungary          HUN
# 18              Greece          GRC
# 19              Serbia          SRB
#
#                                          Series Name     Series Code  \
# 0   Individuals using the Internet (% of population)  IT.NET.USER.ZS
# ...

# %%
df= df[["Country Name",'Series Name','2015 [YR2015]','2016 [YR2016]','2017 [YR2017]','2018 [YR2018]','2019 [YR2019]','2020 [YR2020]']]

# %%
df.head(1)
# Out:
#      Country Name                                       Series Name  \
# 0  United Kingdom  Individuals using the Internet (% of population)
#
#    2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  \
# 0        92.0003      94.775801       90.42455      90.692009      92.516629
#
#    2020 [YR2020]
# 0      94.818201

# %%
dflimpio= df.iloc[0:20]

# %%
dflimpio= dflimpio.rename(columns={'Country Name':'Country',"2015 [YR2015]":"2015","2016 [YR2016]":"2016",'2017 [YR2017]':'2017','2018 [YR2018]':'2018','2019 [YR2019]':'2019','2020 [YR2020]':'2020'})
dflimpio
# Out:
#                Country                                       Series Name  \
# 0       United Kingdom  Individuals using the Internet (% of population)
# 1        United States  Individuals using the Internet (% of population)
# 2               Canada  Individuals using the Internet (% of population)
# 3            Australia  Individuals using the Internet (% of population)
# 4               Brazil  Individuals using the Internet (% of population)
# 5   Russian Federation  Individuals using the Internet (% of population)
# 6                India  Individuals using the Internet (% of population)
# 7                China  Individuals using the Internet (% of population)
# 8         South Africa  Individuals using the Internet (% of population)
# 9                Spain  Individuals using the Internet (% of population)
# 10            Portugal  Individuals using the Internet (% of population)
# 11              France  Individuals using the Internet (% of population)
# ...

# %%
dfinternet =dflimpio.melt(id_vars = 'Country', value_vars = ['2015', '2016', '2017', '2018', '2019', '2020'])

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfinternet= dfinternet.replace({"Russian Federation":'Russia'})

# %%
#df.replace({"0-17": 17, "+55": 60})

# %%
dfinternet.sample(30)
# Out:
#             Country variable      value
# 58           Greece     2017  69.892971
# 96          Romania     2019  73.657476
# 36          Romania     2016  59.503951
# 79           Serbia     2018  73.360709
# 28     South Africa     2016  54.000000
# 60   United Kingdom     2018  90.692009
# 88     South Africa     2019  68.200000
# 16          Romania     2015  55.763156
# 108    South Africa     2020  70.000000
# 63        Australia     2018  87.600000
# 56          Romania     2017  63.747282
# 106           India     2020  43.000000
# 99           Serbia     2019  77.416774
# 72            Italy     2018  74.387183
# 93          Germany     2019  88.134517
# 101   United States     2020  90.900000
# 2            Canada     2015  90.000000
# 86            India     2019  29.400000
# 103       Australia     2020  89.600000
# 100  United Kingdom     2020  94.818201
# 65           Russia     2018  80.864722
# 104          Brazil     2020  81.342694
# ...

# %%
dfinternet.to_excel("internetpaisesBueno.xlsx")

# %%
#

# %% [markdown]
# **GASTO EN SANIDAD**

# %%
df2 = pd.read_excel('sucio/gastoensaludgpd2015-2020.xlsx')

# %%
df2
# Out:
#                                         Country Name Country Code  \
# 0                                          Australia          AUS
# 1                                             Brazil          BRA
# 2                                              China          CHN
# 3                                             France          FRA
# 4                                            Germany          DEU
# 5                                              India          IND
# 6                                              Italy          ITA
# 7                                 Russian Federation          RUS
# 8                                              Spain          ESP
# 9                                     United Kingdom          GBR
# 10                                     United States          USA
# 11                                            Canada          CAN
# 12                                      South Africa          ZAF
# ...

# %%
df2= df2[["Country Name",'Series Name','2015 [YR2015]','2016 [YR2016]','2017 [YR2017]','2018 [YR2018]','2019 [YR2019]','2020 [YR2020]']]

# %%
df2
# Out:
#                                         Country Name  \
# 0                                          Australia
# 1                                             Brazil
# 2                                              China
# 3                                             France
# 4                                            Germany
# 5                                              India
# 6                                              Italy
# 7                                 Russian Federation
# 8                                              Spain
# 9                                     United Kingdom
# 10                                     United States
# 11                                            Canada
# 12                                      South Africa
# 13                                          Portugal
# 14                                           Finland
# 15                                          Bulgaria
# 16                                            Greece
# ...

# %%
dflimpio= df2.iloc[0:20]

# %%
dflimpio= dflimpio.rename(columns={'Country Name':'Country',"2015 [YR2015]":"2015","2016 [YR2016]":"2016",'2017 [YR2017]':'2017','2018 [YR2018]':'2018','2019 [YR2019]':'2019','2020 [YR2020]':'2020'})
dflimpio
# Out:
#                Country                            Series Name       2015  \
# 0            Australia  Current health expenditure (% of GDP)   9.327589
# 1               Brazil  Current health expenditure (% of GDP)   8.909295
# 2                China  Current health expenditure (% of GDP)   4.938280
# 3               France  Current health expenditure (% of GDP)  11.447556
# 4              Germany  Current health expenditure (% of GDP)  11.183703
# 5                India  Current health expenditure (% of GDP)   3.595660
# 6                Italy  Current health expenditure (% of GDP)   8.856892
# 7   Russian Federation  Current health expenditure (% of GDP)   5.296044
# 8                Spain  Current health expenditure (% of GDP)   9.126172
# 9       United Kingdom  Current health expenditure (% of GDP)   9.900724
# 10       United States  Current health expenditure (% of GDP)  16.524073
# 11              Canada  Current health expenditure (% of GDP)  10.733205
# ...

# %%
dfsanidad =dflimpio.melt(id_vars = 'Country', value_vars = ['2015', '2016', '2017', '2018', '2019', '2020'])

# %%
dfsanidad= dfsanidad.replace({"Russian Federation":'Russia'})

# %%
dfsanidad.sample(30)
# Out:
#            Country variable      value
# 113       Portugal     2020         ..
# 78         Romania     2018   5.560508
# 117         Serbia     2020         ..
# 17          Serbia     2015     8.8132
# 87          Russia     2019   5.648491
# 12    South Africa     2015    8.79019
# 116         Greece     2020         ..
# 39         Hungary     2016   6.995352
# 30   United States     2016  16.844324
# 23          France     2016  11.471637
# 14         Finland     2015   9.645239
# 92    South Africa     2019   9.109355
# 75        Bulgaria     2018   7.343425
# 82           China     2019   5.350278
# 119        Hungary     2020         ..
# 103         France     2020         ..
# 50   United States     2017  16.805836
# 72    South Africa     2018   8.858297
# 111         Canada     2020         ..
# 45           India     2017   2.935977
# 74         Finland     2018   9.036085
# 114        Finland     2020         ..
# 107         Russia     2020         ..
# ...

# %%
dfsanidad.to_excel("sanidadGDP.xlsx")

# %% [markdown]
# **GASTO EN EDUCACION**

# %%
df3 = pd.read_excel('sucio/educacion.xlsx')

# %%
df3limpio= df3limpio.rename(columns={'Country Name':'Country',"2015 [YR2015]":"2015","2016 [YR2016]":"2016",'2017 [YR2017]':'2017','2018 [YR2018]':'2018','2019 [YR2019]':'2019','2020 [YR2020]':'2020'})
df3limpio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-9079e2939b78> in <module>
# ----> 1 df3limpio= df3limpio.rename(columns={'Country Name':'Country',"2015 [YR2015]":"2015","2016 [YR2016]":"2016",'2017 [YR2017]':'2017','2018 [YR2018]':'2018','2019 [YR2019]':'2019','2020 [YR2020]':'2020'})
#       2 df3limpio
#
# NameError: name 'df3limpio' is not defined

# %% [markdown]
# **EDUCACION 2 (BUENO)**

# %%
df4 = pd.read_excel('datos/educacion.xlsx')

# %%
#####################################################333333
